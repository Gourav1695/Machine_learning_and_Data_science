# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
placement_data=pd.read_csv('/kaggle/input/brain-dead-placement-data/Placement_Data_Full_Class.csv')
placement_data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
placement_data.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
placement_data=placement_data.drop(['sl_no'],axis=1)

# %%
placement_data.head(10)
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3      M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4      M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# 5      M  55.00   Others  49.80   Others   Science     67.25   Sci&Tech
# 6      F  46.00   Others  49.20   Others  Commerce     79.00  Comm&Mgmt
# 7      M  82.00  Central  64.00  Central   Science     66.00   Sci&Tech
# 8      M  73.00  Central  79.00  Central  Commerce     72.00  Comm&Mgmt
# 9      M  58.00  Central  70.00  Central  Commerce     61.00  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p      status    salary
# 0     No    55.00         Mkt&HR  58.80      Placed  270000.0
# ...

# %%
placement_data.describe()
# Out:
#             ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000
# mean    67.303395   66.333163   66.370186   72.100558   62.278186
# std     10.827205   10.897509    7.358743   13.275956    5.833385
# min     40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     60.600000   60.900000   61.000000   60.000000   57.945000
# 50%     67.000000   65.000000   66.000000   71.000000   62.000000
# 75%     75.700000   73.000000   72.000000   83.500000   66.255000
# max     89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# ##  Removing the Null value from the Data Set

# %%
placement_data=placement_data.fillna(0,axis=1)

# %%
placement_data.isnull().sum()
# Out:
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
print(placement_data.gender.value_counts())
# Out:
# M    139
# F     76
# Name: gender, dtype: int64

# %%
sns.boxplot( data=placement_data,x='salary',y='gender')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='gender'>

# %%
sns.countplot(hue='status',data=placement_data,x='gender')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
placement_data.groupby('gender')['status'].value_counts(normalize=False)
# Out:
# gender  status
# F       Placed         48
#         Not Placed     28
# M       Placed        100
#         Not Placed     39
# Name: status, dtype: int64

# %%
sns.boxplot( data=placement_data,x='salary',y='ssc_b')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='ssc_b'>

# %%
sns.countplot(hue='status',data=placement_data,x='ssc_b');

# %%
placement_data.groupby('ssc_b')['status'].value_counts(normalize=False)
# Out:
# ssc_b    status
# Central  Placed        78
#          Not Placed    38
# Others   Placed        70
#          Not Placed    29
# Name: status, dtype: int64

# %%
sns.boxplot( data=placement_data,x='salary',y='hsc_b');

# %%
placement_data.groupby('hsc_b')['status'].value_counts(normalize=False)
# Out:
# hsc_b    status
# Central  Placed        57
#          Not Placed    27
# Others   Placed        91
#          Not Placed    40
# Name: status, dtype: int64

# %% [markdown]
# ##### Students from non-central boards appear to have higher placement percentages compared to those from central boards. However, when it comes to median salaries, there isn't a significant difference between the two groups, except for one outlier in the case of central board students who have landed their dream job.

# %%
sns.boxplot( data=placement_data,x='salary',y='workex');

# %% [markdown]
# #####  Students having prior workex have more median and the starting salary than people with no work experince and majority of the High paying jobs land for the students having prior workex

# %%
placement_data.groupby('workex')['status'].value_counts(normalize=False)
# Out:
# workex  status
# No      Placed        84
#         Not Placed    57
# Yes     Placed        64
#         Not Placed    10
# Name: status, dtype: int64

# %%
sns.boxplot( data=placement_data,x='salary',y='specialisation');

# %% [markdown]
# ##### When it comes to specializations in higher education, it appears that students who focus on Marketing and Finance tend to have higher median and starting salaries compared to those in Human Resources.

# %%
placement_data.groupby('specialisation')['status'].value_counts(normalize=False)
# Out:
# specialisation  status
# Mkt&Fin         Placed        95
#                 Not Placed    25
# Mkt&HR          Placed        53
#                 Not Placed    42
# Name: status, dtype: int64

# %%
sns.countplot(hue='status',data=placement_data,x='specialisation');

# %% [markdown]
# ##### Having a strong focus on finance has proven to be a valuable attribute for students, as it often leads to excellent career opportunities with impressive compensation packages. Many students who specialize in finance find themselves in high demand by top employers seeking candidates with a deep understanding of financial markets and analysis. The potential for lucrative salaries and career growth within the finance industry is a strong motivator for students to pursue this field of study.

# %%
sns.boxplot( data=placement_data,x='salary',y='hsc_s');

# %%
placement_data.groupby('hsc_s')['status'].value_counts(normalize=False)
# Out:
# hsc_s     status
# Arts      Placed         6
#           Not Placed     5
# Commerce  Placed        79
#           Not Placed    34
# Science   Placed        63
#           Not Placed    28
# Name: status, dtype: int64

# %% [markdown]
# ##### We have very less students for arts, hence cannot determine if this seems to be an important feature as it is an imbalanced datatset with less number of arts entry

# %%
sns.regplot( data=placement_data,x='salary',y='ssc_p');

# %%
sns.regplot( data=placement_data,x='salary',y='hsc_p');

# %%
sns.regplot( data=placement_data,x='salary',y='degree_p');

# %%
sns.scatterplot( data=placement_data,x='salary',y='mba_p');

# %%
sns.regplot( data=placement_data,x='salary',y='mba_p');

# %%
sns.scatterplot( data=placement_data,x='salary',y='etest_p');

# %%
sns.regplot( data=placement_data,x='salary',y='mba_p');

# %%
sns.pairplot(data=placement_data);

# %%
placement_data.corr()['salary'].sort_values(ascending=False)
# Out:
# salary     1.00
# ssc_p      0.54
# hsc_p      0.45
# degree_p   0.41
# etest_p    0.19
# mba_p      0.14
# Name: salary, dtype: float64

# %%
sns.catplot( data=placement_data,x='status',y='ssc_p');

# %% [markdown]
# ### By seeing this plot we can say that Students with less persentage than about 60 % do not get placed..

# %%
sns.catplot( data=placement_data,x='status',y='hsc_p',col="status");

# %%
sns.catplot( data=placement_data,x='status',y='degree_p');

# %% [markdown]
# ### Students having less than 60% do not get placed can be infered

# %%
sns.regplot( data=placement_data,x='degree_p',y='hsc_p');

# %%
sns.regplot( data=placement_data,x='mba_p',y='degree_p');

# %%
sns.regplot( data=placement_data,x='etest_p',y='degree_p');
